# %% [markdown]
# <a href="https://colab.research.google.com/github/aditheyanns-png/resume/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/fraudTest.csv")
df
# Out:
#                                                                                                                                                                                                                                                                                                dc5dca5  \
# 205657 2020-09-01 07:41:38 2720012583106919 fraud_Bauch-Raynor                 grocery_pos   124.98 Joseph  Murray    M 42933 Ryan Underpass         Manderson        SD 57756 43.3526 -102.5411 1126   Volunteer coordinator                             1980-08-18  7f6846ccbf6e3809aaa7fa8f29430dcb
# 205658 2020-09-01 07:41:41 6011626928491360 fraud_Casper, Hand and Zulauf      grocery_pos   79.05  Heather Roberts   F 62934 Maria Cliffs Suite 350 Bethel Springs   TN 38315 35.2289 -88.6440  3876   Senior tax professional/tax inspector             1960-11-19  9b7d7e452d602551257a38c3555db738
# ...

# %%
df=pd.read_csv("/content/fraudTrain.csv")
df
# Out:
#                        0:41  5559857416065248  \
# 213447  2019-04-19 06:50:59      4.922711e+15
# 213448  2019-04-19 06:52:27      3.615388e+13
# 213449  2019-04-19 06:53:10      4.736845e+18
# 213450  2019-04-19 06:54:17      2.131936e+14
# 213451  2019-04-19 06:55:15      4.642255e+15
# ...                     ...               ...
# 275402  2019-05-16 13:29:05      3.725200e+14
# 275403  2019-05-16 13:29:14      4.239436e+12
# 275404  2019-05-16 13:33:30      6.304250e+11
# 275405  2019-05-16 13:33:37      3.027043e+13
# 275406                  NaN               NaN
#
#                          fraud_Terry-Huel   shopping_net    1.63      Jack  \
# 213447                 fraud_Kassulke PLC   shopping_net    5.81   Heather
# 213448              fraud_Brekke and Sons  gas_transport   67.49      Erik
# 213449             fraud_Erdman-Kertzmann  gas_transport   44.59      Toni
# 213450  fraud_Goldner, Kovacek and Abbott    grocery_pos   97.49     James
# ...

# %%
df.isnull().any()
# Out:
# 0:41                                True
# 5559857416065248                    True
# fraud_Terry-Huel                    True
# shopping_net                        True
# 1.63                                True
# Jack                                True
# Hill                                True
# M                                   True
# 5916 Susan Bridge Apt. 939          True
# Grenada                             True
# CA                                  True
# 96038                               True
# 41.6125                             True
# -122.5258                           True
# 589                                 True
# Systems analyst                     True
# 1945-12-21                          True
# 53a49f412492a47c420b7d288747e548    True
# 1334818241                          True
# 41.921690999999996                  True
# -121.658643                         True
# 0                                   True
# dtype: bool

# %%
df.dtypes
# Out:
# 0:41                                 object
# 5559857416065248                    float64
# fraud_Terry-Huel                     object
# shopping_net                         object
# 1.63                                float64
# Jack                                 object
# Hill                                 object
# M                                    object
# 5916 Susan Bridge Apt. 939           object
# Grenada                              object
# CA                                   object
# 96038                               float64
# 41.6125                             float64
# -122.5258                           float64
# 589                                 float64
# Systems analyst                      object
# 1945-12-21                           object
# 53a49f412492a47c420b7d288747e548     object
# 1334818241                          float64
# 41.921690999999996                  float64
# -121.658643                         float64
# ...
